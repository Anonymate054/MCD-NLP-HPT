# %%
from sklearn.model_selection import train_test_split
import pandas as pd
import fs

# %%
INTERIM_FILES_DIR = fs.open_fs("MCD-NLP-HPT/data/interim")
INTERIM_COMMENTS_ITEMS_DIR = INTERIM_FILES_DIR.getsyspath("Comments_cleaned.csv")

PROCESSED_FILES_DIR = fs.open_fs("MCD-NLP-HPT/data/processed")
TRAIN_DIR = PROCESSED_FILES_DIR.getsyspath("train.csv")
TEST_DIR = PROCESSED_FILES_DIR.getsyspath("test.csv")
VAL_DIR = PROCESSED_FILES_DIR.getsyspath("validation.csv")

X_TRAIN_DIR = PROCESSED_FILES_DIR.getsyspath("x_train.csv")
X_TEST_DIR = PROCESSED_FILES_DIR.getsyspath("x_test.csv")
X_VAL_DIR = PROCESSED_FILES_DIR.getsyspath("x_val.csv")

Y_TRAIN_DIR = PROCESSED_FILES_DIR.getsyspath("y_train.csv")
Y_TEST_DIR = PROCESSED_FILES_DIR.getsyspath("y_test.csv")
Y_VAL_DIR = PROCESSED_FILES_DIR.getsyspath("y_val.csv")

# %%
df = pd.read_csv(INTERIM_COMMENTS_ITEMS_DIR)

# %%
# Cleaning null values

# %%
df['category_id'] = df['category_id'].astype('category')
# df['category_description'] = df['category_description'].astype('category')

# %%
df
# Out:
#                               id      videoId  \
# 0     Ugz0QmXyVLSM0nUK7kB4AaABAg  cQ9RLDhq6JY
# 1     UgyJhRBhVcbyStZdxjR4AaABAg  cQ9RLDhq6JY
# 2     UgzT1q2am7kMEM5ckDp4AaABAg  cQ9RLDhq6JY
# 3     Ugyckucg38lqZFdZhaR4AaABAg  cQ9RLDhq6JY
# 4     UgzhZHVt-tEbDpbCvtB4AaABAg  cQ9RLDhq6JY
# ...                          ...          ...
# 1020  Ugyuq-tSoKFj7HEnAQ54AaABAg  t3MogAmkMUg
# 1021  Ugy2h_vD89gf_8eeFph4AaABAg  t3MogAmkMUg
# 1022  Ugx7vBivUc-z-n8H76t4AaABAg  t3MogAmkMUg
# 1023  Ugzvu7xFsIUo8ibNXPJ4AaABAg  t3MogAmkMUg
# 1024  Ugx6mGMWrp3CU7o7Lwd4AaABAg  t3MogAmkMUg
#
#                                            textOriginal  \
# 0     Me gusta su podcast, pero solo he escuchado lo...
# 1                                               weeeeey
# 2                 Les voy a enviar una foto de TARAPACA
# 3     Entonces Teca esta  solterooooooooooooooo! ❤  ...
# 4     Me encantan sus podcast, los escucho en spotif...
# ...                                                 ...
# 1020  Justo a tiempo para hacerme pndja en el trabaj...
# 1021  Ya que son Otakus declarados, les recomiendo e...
# 1022   Pero dejen hablar al invitado, chavos banda!! :D
# 1023  El primer metal no sería el Na cuando el human...
# 1024                A tiempo para mi novela favorita 👌🏽
#
#                authorDisplayName  likeCount           publishedAt category_id  \
# 0             @fabianbecerra2272          0  2024-07-15T12:41:43Z           1
# 1              @SantiagoItzcoatl          0  2024-05-26T21:41:04Z           7
# 2                     @Sonyeke_1          0  2024-05-23T22:06:21Z           7
# 3           @alejandranavarro464          0  2024-05-05T09:24:57Z           6
# 4           @fiorellamartinez873          0  2024-04-21T21:09:08Z           5
# ...                          ...        ...                   ...         ...
# 1020      @estefaniasandoval9999          0  2024-08-19T19:46:46Z           6
# 1021    @medinamartinezdavid8052          0  2024-08-19T19:33:41Z           2
# 1022                @hoffnerbass          1  2024-08-19T19:33:18Z           1
# 1023  @LuisAndresOtalvaroSanchez          0  2024-08-19T19:13:00Z           4
# 1024              @hugogomez2232          0  2024-08-19T18:55:54Z           7
#
#                   category_description  \
# 0       Quejas o sugerencias de mejora
# 1                Comentarios generales
# 2                Comentarios generales
# 3     Comentarios humorísticos o memes
# 4     Felicitaciones y agradecimientos
# ...                                ...
# 1020  Comentarios humorísticos o memes
# 1021      Propuestas y recomendaciones
# 1022    Quejas o sugerencias de mejora
# 1023  Correcciones o datos adicionales
# 1024             Comentarios generales
#
#                                             Tokens_full  \
# 0     ['Me', 'gusta', 'su', 'podcast', ',', 'pero', ...
# 1                                           ['weeeeey']
# 2     ['Les', 'voy', 'a', 'enviar', 'una', 'foto', '...
# 3     ['Entonces', 'Teca', 'esta', 'solteroooooooooo...
# 4     ['Me', 'encantan', 'sus', 'podcast', ',', 'los...
# ...                                                 ...
# 1020  ['Justo', 'a', 'tiempo', 'para', 'hacerme', 'p...
# 1021  ['Ya', 'que', 'son', 'Otakus', 'declarados', '...
# 1022  ['Pero', 'dejen', 'hablar', 'al', 'invitado', ...
# 1023  ['El', 'primer', 'metal', 'no', 'sería', 'el',...
# 1024  ['A', 'tiempo', 'para', 'mi', 'novela', 'favor...
#
#                                                  Tokens  \
# 0     ['Me', 'gusta', 'su', 'podcast', 'pero', 'solo...
# 1                                           ['weeeeey']
# 2     ['Les', 'voy', 'a', 'enviar', 'una', 'foto', '...
# 3     ['Entonces', 'Teca', 'esta', 'solteroooooooooo...
# 4     ['Me', 'encantan', 'sus', 'podcast', 'los', 'e...
# ...                                                 ...
# 1020  ['Justo', 'a', 'tiempo', 'para', 'hacerme', 'p...
# 1021  ['Ya', 'que', 'son', 'Otakus', 'declarados', '...
# 1022  ['Pero', 'dejen', 'hablar', 'al', 'invitado', ...
# 1023  ['El', 'primer', 'metal', 'no', 'sería', 'el',...
# 1024  ['A', 'tiempo', 'para', 'mi', 'novela', 'favor...
#
#                                Tokens_without_stopwords  \
# 0     ['Me', 'gusta', 'podcast', 'solo', 'escuchado'...
# 1                                           ['weeeeey']
# 2          ['Les', 'voy', 'enviar', 'foto', 'TARAPACA']
# 3     ['Entonces', 'Teca', 'solterooooooooooooooo', ...
# 4     ['Me', 'encantan', 'podcast', 'escucho', 'spot...
# ...                                                 ...
# 1020  ['Justo', 'tiempo', 'hacerme', 'pndja', 'traba...
# 1021  ['Ya', 'Otakus', 'declarados', 'recomiendo', '...
# 1022  ['Pero', 'dejen', 'hablar', 'invitado', 'chavo...
# 1023  ['El', 'primer', 'metal', 'Na', 'humano', 'uti...
# 1024              ['A', 'tiempo', 'novela', 'favorita']
#
#                        Tokens_without_stopwords_stemmed  \
# 0     ['me', 'gust', 'podcast', 'sol', 'escuch', 'yo...
# 1                                           ['weeeeey']
# 2              ['les', 'voy', 'envi', 'fot', 'tarapac']
# 3     ['entonc', 'tec', 'solteroooooooooooooo', 'woo...
# 4     ['me', 'encant', 'podcast', 'escuch', 'spotify...
# ...                                                 ...
# 1020  ['just', 'tiemp', 'hac', 'pndja', 'trabaj', 'b...
# 1021  ['ya', 'otakus', 'declar', 'recom', 'anim', 'd...
# 1022  ['per', 'dej', 'habl', 'invit', 'chav', 'band'...
# 1023  ['el', 'prim', 'metal', 'na', 'human', 'utiliz...
# 1024                 ['a', 'tiemp', 'novel', 'favorit']
#
#                                       Tokens_lemmatized  \
# 0     ['yo', 'gustar', 'su', 'podcast', ',', 'pero',...
# 1                                           ['weeeeey']
# 2     ['él', 'ir', 'a', 'enviar', 'uno', 'foto', 'de...
# 3     ['entonces', 'teca', 'estar', 'solterooooooooo...
# 4     ['yo', 'encantar', 'su', 'podcast', ',', 'él',...
# ...                                                 ...
# 1020  ['justo', 'a', 'tiempo', 'para', 'hacer', 'yo'...
# 1021  ['ya', 'que', 'ser', 'otakus', 'declarado', ',...
# 1022  ['pero', 'dejar', 'hablar', 'a', 'el', 'invita...
# 1023  ['el', 'primero', 'metal', 'no', 'ser', 'el', ...
# 1024  ['a', 'tiempo', 'para', 'mi', 'novela', 'favor...
#
#                     Tokens_without_stopwords_lemmatized
# 0     ['yo', 'gustar', 'podcast', 'sólo', 'escuchar'...
# 1                                           ['weeeeey']
# 2            ['él', 'ir', 'enviar', 'foto', 'tarapaca']
# 3     ['entonces', 'teca', 'solterooooooooooooooo', ...
# 4     ['yo', 'encantar', 'podcast', 'escuchar', 'spo...
# ...                                                 ...
# 1020  ['justo', 'tiempo', 'hacer', 'pndja', 'trabajo...
# 1021  ['ya', 'otakus', 'declarado', 'recomer', 'anim...
# 1022  ['pero', 'dejar', 'hablar', 'invitado', 'chavo...
# 1023  ['el', 'primero', 'metal', 'na', 'humano', 'ut...
# 1024              ['a', 'tiempo', 'novela', 'favorita']
#
# [1025 rows x 14 columns]

# %% [markdown]
# # Separación de datos de prueba y de entrenamiento

# %%
train_df, test_df = train_test_split(df, test_size=0.1,random_state=1)
test_df, val_df = train_test_split(test_df, test_size=0.1, random_state=1)

# %%
def calculate_category_percentages(df):
    """
    Calculate the percentage of each category in all categorical columns of a DataFrame.
    
    Parameters:
        df (pd.DataFrame): The input DataFrame.
        
    Returns:
        pd.DataFrame: A DataFrame containing columns, categories, and their percentages.
    """
    per_data = []

    # Iterate over columns with categorical dtype
    for col in df.select_dtypes(include=['category']):
        # Calculate value counts as percentages
        percentages = df[col].value_counts(normalize=True) * 100
        # Append data for each category
        for category, percentage in percentages.items():
            per_data.append({'Column': col, 'Category': category, 'Percentage': percentage})

    # Return the result as a DataFrame
    return pd.DataFrame(per_data)

# %%
def generate_report_for_datasets(dataset_dict):
    """
    Generate a report of category percentages for multiple datasets.
    
    Parameters:
        dataset_dict (dict): A dictionary where keys are dataset names and values are DataFrames.
        
    Returns:
        dict: A dictionary where keys are dataset names and values are DataFrames with percentages.
    """
    reports = {}
    for name, df in dataset_dict.items():
        reports[name] = calculate_category_percentages(df)
    return reports

# %%
datasets = {
    "Train Data": train_df,
    "Validation Data": val_df,
    "Test Data": test_df
}

# Generate reports
reports = generate_report_for_datasets(datasets)

# Display results
for dataset_name, report in reports.items():
    print(f"--- {dataset_name} ---")
    print(report)
# Out:
# --- Train Data ---
#         Column  Category  Percentage
# 0  category_id         6   22.342733
# 1  category_id         5   21.041215
# 2  category_id         2   16.377440
# 3  category_id         4   12.472885
# 4  category_id         7   12.147505
# 5  category_id         1    8.893709
# 6  category_id         3    6.724512
# --- Validation Data ---
#         Column  Category  Percentage
# 0  category_id         2   27.272727
# 1  category_id         4   18.181818
# 2  category_id         6   18.181818
# 3  category_id         7   18.181818
# 4  category_id         3    9.090909
# 5  category_id         5    9.090909
# 6  category_id         1    0.000000
# --- Test Data ---
#         Column  Category  Percentage
# 0  category_id         2   26.086957
# 1  category_id         5   25.000000
# 2  category_id         6   18.478261
# 3  category_id         4   13.043478
# 4  category_id         1    7.608696
# 5  category_id         7    5.434783
# 6  category_id         3    4.347826

# %%
train_df.to_csv(TRAIN_DIR, index=False, encoding="utf-8")
test_df.to_csv(TEST_DIR, index=False, encoding="utf-8")
val_df.to_csv(VAL_DIR, index=False, encoding="utf-8")

# %% [markdown]
# # Spliting the dataset into train, test and validation set

# %%
x_train_df = train_df.drop(['category_id'], axis=1)
y_train_df = train_df['category_id']

x_test_df = test_df.drop(['category_id'], axis=1)
y_test_df = test_df['category_id']

x_val_df = val_df.drop(['category_id'], axis=1)
y_val_df = val_df['category_id']

# %%
x_train_df.to_csv(X_TRAIN_DIR, index=False, encoding="utf-8")
x_test_df.to_csv(X_TEST_DIR, index=False, encoding="utf-8")
x_val_df.to_csv(X_VAL_DIR, index=False, encoding="utf-8")

y_train_df.to_csv(Y_TRAIN_DIR, index=False, encoding="utf-8")
y_test_df.to_csv(Y_TEST_DIR, index=False, encoding="utf-8")
y_val_df.to_csv(Y_VAL_DIR, index=False, encoding="utf-8")

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=2820e488-6f1b-466d-af14-a66826f012e3' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
