# %% [markdown]
# # Libraries

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import json
import fs
import re

# %%
PROCESSED_FILES_DIR = fs.open_fs("../../data/processed")
PROCESSED_COMMENTS_COMBINED_DIR = PROCESSED_FILES_DIR.getsyspath("Combined.csv")
PROCESSED_COMMENTS_REPLIES_DIR = PROCESSED_FILES_DIR.getsyspath("Replies.csv")
PROCESSED_COMMENTS_ITEMS_DIR = PROCESSED_FILES_DIR.getsyspath("Items.csv")

# %%
df_items = pd.read_csv(PROCESSED_COMMENTS_ITEMS_DIR)
# df_combined = pd.read_csv(PROCESSED_COMMENTS_COMBINED_DIR)
df_replies = pd.read_csv(PROCESSED_COMMENTS_REPLIES_DIR)

# %%
df_replies
# Out:
#                kind                         etag  \
# 0   youtube#comment  a7mOGAgSO3DCwrGCaZ2qo99j0C8
# 1   youtube#comment  m5VqhYbtIPyhwrxzQIogNS5uYOY
# 2   youtube#comment  oIlsSAnhenE4ze8uxogX8HZUm_M
# 3   youtube#comment  osDSuPjtUD3xbxQT3b6O89iQzoQ
# 4   youtube#comment  mIMpZjMGIWDZvfHCf-oYxs7y21k
# ..              ...                          ...
# 83  youtube#comment  x3ZrMzmUW-TnDevonrjS2AL13NU
# 84  youtube#comment  JbEfqVnlCF4GJN7sUQzGzVEpiZM
# 85  youtube#comment  YFW2Z6AkxPr81tmyziZuyAyTkpk
# 86  youtube#comment  8dw98axroLiBkJaPz86NhbCFINA
# 87  youtube#comment  Muvk9KxuyomK_ItnQvwAQSLlyK4
#
#                                                    id  \
# 0   Ugwt4G1SOIkcXe9YaKV4AaABAg.A27qlBtgdhtA28Lccpmg3z
# 1   UgwqU9XKaUKE-CxWiWJ4AaABAg.A21bgH6IvK_A239CeCK6uD
# 2   UgwlhBiP-mENRCZKoL54AaABAg.A5jmxsrpkMRA5lIZT8f7x1
# 3   UgxngCKROSPHzg7uvLN4AaABAg.A5eZCtIJkGYA5ebz0P5EWA
# 4   UgyaMcb3uZ_AzDKExtl4AaABAg.A5eWZN1BW8EA5fdb7KLVkx
# ...

# %%
df_items
# Out:
#                        kind                         etag  \
# 0     youtube#commentThread  35SzVbfAjbh-WxxI6CDcz8jJalE
# 1     youtube#commentThread  D5l-LBB9fD-VlBImz-EN9K8mTmM
# 2     youtube#commentThread  iKN6FQSPLo3xUlizd--6R0h2SN8
# 3     youtube#commentThread  hkErqy7RZOwAKS6YyNXqwPFTCAg
# 4     youtube#commentThread  9c50dNDxQ96ZYyFK1aeJYj4ofnQ
# ...                     ...                          ...
# 1021  youtube#commentThread  8wSxk2QdKgz2v0AUy3EsWvUOxSU
# 1022  youtube#commentThread  X4xqkZX0x2OmHUMWh4fe2ck4iGA
# 1023  youtube#commentThread  btoZQh1KTx4_A0e8kLI3d4BAUmg
# 1024  youtube#commentThread  Xf-HPCYvwS0mb7JyqR4t_eoHZx4
# 1025  youtube#commentThread  OBq15WOOkVZGkZnpWOHgG9R_IwA
#
#                               id         snippet.channelId snippet.videoId  \
# 0     Ugz0QmXyVLSM0nUK7kB4AaABAg  UCeYSnd34IPe57sM8hkjWhrw     cQ9RLDhq6JY
# 1     UgyJhRBhVcbyStZdxjR4AaABAg  UCeYSnd34IPe57sM8hkjWhrw     cQ9RLDhq6JY
# ...

# %%
df_items["snippet.videoId"].value_counts()
# Out:
# snippet.videoId
# RBnZPFhDcnk    83
# ShW6FY-vbmo    59
# FOFeh_vfcD8    59
# qSjSUN6Rxhk    57
# PAFwYBqf_Os    56
# CPCN1Lqzc2U    55
# QO_mORdhchw    50
# J5dH-jKp-ac    50
# yFHCam_Q9j4    49
# FXxcNjTZ4qo    48
# rx108V8Ydtc    45
# t3MogAmkMUg    44
# HxMXLWqe9HQ    42
# 0IDFrBktWIA    40
# cOxTBBHDN-0    37
# o7l_d75l-eo    34
# 5Uac-LKCY4Y    27
# Vhf-VeTykO8    26
# 0kY6Qt1V8Kc    26
# cQ9RLDhq6JY    26
# 7Jo3NR5lgd8    25
# rXd-HsVezzs    24
# kSRLcVrXYSY    23
# Go2KlhN4cQk    22
# wCm4FNSnDPs    19
# Name: count, dtype: int64

# %%
df_ = df_items[df_items["snippet.videoId"] == "7Jo3NR5lgd8"]
df_c = df_[["snippet.topLevelComment.snippet.textDisplay", "snippet.topLevelComment.snippet.likeCount"]].sort_values(by="snippet.topLevelComment.snippet.likeCount", ascending=False)
df_c
# Out:
#            snippet.topLevelComment.snippet.textDisplay  \
# 768  Voy a investigar el conflicto de myanmar, ahor...
# 760  Hola, yo los escucho en Amazon music, desde qu...
# 759                                              🇯🇴 🫶🏻
# 758                                 Palestina libre 🇯🇴
# 762  El episodio más esperado por toda Latinoaméric...
# 761                  A mí sí me gustan las pasas😂!!!!!
# 756  Siento que chile es el país que se menciona pa...
# 763  Los árabes no eran dueños de esa región, así q...
# 769  Loviu chicos ✨ ya estaba esperando la continua...
# 770  Buenas un saludo para cuando hablan de la mito...
# 771                                           SIuuuuuu
# 750  Yo todos los capítulos de usteds los escucho e...
# 766  El 7 de octubre del 2023 no se olvidará VIVA I...
# 751  Considero que se debió platicar con poco más d...
# 749                                        Ah perros 🤟
# 748  espero cuenten como una fuente de consulta val...
# ...
